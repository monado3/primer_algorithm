# %%
require "zlib"
def show(image)
 def chunk(type, data)
   [data.bytesize, type, data, Zlib.crc32(type + data)].pack("NA4A*N")
 end
 def make_png(raw_data)
   height = raw_data.size
   width = raw_data[0].size
   s = "\x89PNG\r\n\x1a\n".force_encoding("ascii-8bit")
   s1 = chunk("IHDR", [width, height, 8, 2, 0, 0, 0].pack("NNCCCCC"))
   s2 = chunk("IDAT", Zlib::Deflate.deflate(raw_data.map {|line|
                        ([0] + line.flatten).pack("C*") }.join))
   s3 = chunk("IEND", "")
   s + s1 + s2 + s3
 end
 def to_8bit(c)
   if c.is_a?(Array)
     if c[0].is_a?(Numeric)
       c.map{|e| (e * 255).to_i }
     else
       raise "show(): bad array element " + c.to_s
     end
   else
     [(c * 255).to_i] * 3
   end
 end
 if !image.is_a?(Array) || !image[0].is_a?(Array)
   puts "show(): not a 2d array" ; false
 else
   h = image.size
   s = h < 10 ? 20 : h < 60 ? 10 : h < 400 ? 400 / h : 1
   data = image.flat_map{|r| [r.flat_map{|c| [to_8bit(c)] * s }] * s}
   IRuby.display make_png(data), mime: "image/png" ; true
 end
end
# Out:
# :show

# %%
def make1d(n)
  if n>1 then
    make1d(n-1)+[0]
  else
    [0]
  end
end
def make2d(h,w)
  if h>1 then
    make2d(h-1,w)+[make1d(w)]
  else
    [make1d(w)]
  end
end
# Out:
# :make2d

# %%
def mandelblot(s)
  image=make2d(s,s)
  for x in 0..(s-1)
    for y in 0..(s-1)
      image[y][x]=b((x-s)/50.0,(y-s/2)/50.0)
        end
    end
    image
end
def b(x,y)
    n=0
    r=0.0
    i=0.0
    while r**2+i**2<4 && n<=50 do
      oldR=r
      oldI=i
      n=n+1
      r=oldR**2-oldI**2+x
      i=2*oldR*oldI+y
    end
    if n==51 then 0 else[0,(50-n)/3.0,0] end
end
# Out:
# :b

# %%
show mandelblot(100)
# Out:
# "\x89PNG\r\n\x1A\n\x00\x00\x00\rIHDR\x00\x00\x01\x90\x00\x00\x01\x90\b\x02\x00\x00\x00\x0F\xDD\xA1\x9B\x00\x00\x16\x14IDATx\x9C\xED\xDD\xDD\x92%\xC5y\x85a\xDD\x9C,!\x100\xE8\xF2d`k\x00\x0F\xE8\xEAd\xF1\x0F\x01\xF8\xC0:Xm\xCD\xD7\xCE\xEA\xFD\xF3ef=+\xDE#\xA2\xA7\xD5\xD3\x11\xF5(\"\xA7j\xD7\xEF~\xF7\xFB\xDF\xAD\xD1?&\xEB\xAF\xDA\xBA\xFFX\xB0\xFF\xBEQ\xFF9\xD0\x1F\xA2\x8F\xA3?F\x9FF\xDFD\x1F\x17}]\xF4n\xD4/\x11\xB04a\xED\xFA\x00\vX\xC0\xD2h\xED\xFA\x00\vX\xC0\xD2h\xED\xFA\x00k=\xB0\xDAU\x82\xD4\xA9j\x17gr\xB0\x12\xA9\x7F\x16%@\t\xD6\x0F\xD1'\xD1;\xD1w\xD1\xB7Q\xE2\xD5\xAF\x12\xB04I\xED\xE2\x00\vX\xC0\xD2h\xED\xE2\x00\vX\xC0\xD2h\xED\xE2\x00\vX`\xD2s\xB5+3\tR\