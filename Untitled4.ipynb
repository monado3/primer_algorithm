# %%
def sphere(s)
  def make2d(height,width)
    Array.new(height){Array.new(width,0)}
  end
  def distance(x,y,r,s)
    ((x-r)**2+(y-s)**2)**0.5
  end
  def b(s,x,y)
    r=s/2
    d=distance(x,y,r,s)
    if d<=r
      (r-d)/r
    else
      1
    end  
  end
  image=make2d(s,s)
  for y in 0..(s-1)
    for x in 0..(s-1)
      image[y][x]=b(s,x,y)
    end
  end
  image
end
show(sphere(100))
# Out:
# NoMethodError: undefined method `show' for main:Object
# (pry):50:in `<main>'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `eval'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `evaluate_ruby'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:323:in `handle_line'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:243:in `block (2 levels) in eval'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:242:in `catch'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:242:in `block in eval'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:241:in `catch'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:241:in `eval'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/backend.rb:65:in `eval'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/backend.rb:12:in `eval'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/kernel.rb:87:in `execute_request'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/kernel.rb:47:in `dispatch'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/kernel.rb:37:in `run'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/command.rb:70:in `run_kernel'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/command.rb:34:in `run'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/bin/iruby:5:in `<top (required)>'
# /opt/local/bin/iruby:23:in `load'
# /opt/local/bin/iruby:23:in `<main>'

# %%
require "zlib"
def show(image)
 def chunk(type, data)
   [data.bytesize, type, data, Zlib.crc32(type + data)].pack("NA4A*N")
 end
 def make_png(raw_data)
   height = raw_data.size
   width = raw_data[0].size
   s = "\x89PNG\r\n\x1a\n".force_encoding("ascii-8bit")
   s1 = chunk("IHDR", [width, height, 8, 2, 0, 0, 0].pack("NNCCCCC"))
   s2 = chunk("IDAT", Zlib::Deflate.deflate(raw_data.map {|line|
                        ([0] + line.flatten).pack("C*") }.join))
   s3 = chunk("IEND", "")
   s + s1 + s2 + s3
 end
 def to_8bit(c)
   if c.is_a?(Array)
     if c[0].is_a?(Numeric)
       c.map{|e| (e * 255).to_i }
     else
       raise "show(): bad array element " + c.to_s
     end
   else
     [(c * 255).to_i] * 3
   end
 end
 if !image.is_a?(Array) || !image[0].is_a?(Array)
   puts "show(): not a 2d array" ; false
 else
   h = image.size
   s = h < 10 ? 20 : h < 60 ? 10 : h < 400 ? 400 / h : 1
   data = image.flat_map{|r| [r.flat_map{|c| [to_8bit(c)] * s }] * s}
   IRuby.display make_png(data), mime: "image/png" ; true
 end
end

# %%
def sphere(s)
  def make2d(height,width)
    Array.new(height){Array.new(width,0)}
  end
  def distance(x,y,r,s)
    ((x-r)**2+(y-s)**2)**0.5
  end
  def b(s,x,y)
    r=s/2
    d=distance(x,y,r,s)
    if d<=r
      (r-d)/r
    else
      1
    end  
  end
  image=make2d(s,s)
  for y in 0..(s-1)
    for x in 0..(s-1)
      image[y][x]=b(s,x,y)
    end
  end
  image
end
show(sphere(100))
# Out:
# NoMethodError: undefined method `show' for main:Object
# (pry):75:in `<main>'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `eval'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `evaluate_ruby'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:323:in `handle_line'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:243:in `block (2 levels) in eval'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:242:in `catch'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:242:in `block in eval'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:241:in `catch'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:241:in `eval'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/backend.rb:65:in `eval'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/backend.rb:12:in `eval'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/kernel.rb:87:in `execute_request'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/kernel.rb:47:in `dispatch'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/kernel.rb:37:in `run'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/command.rb:70:in `run_kernel'
# /Library/Zool_nfs/opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/lib/iruby/command.rb:34:in `run'
# /opt/local/lib/ruby2.1/gems/2.1.0/gems/iruby-0.2.9/bin/iruby:5:in `<top (required)>'
# /opt/local/bin/iruby:23:in `load'
# /opt/local/bin/iruby:23:in `<main>'

# %%
include(Math) 
 
require "zlib" 
def show(image) 
 def chunk(type, data) 
   [data.bytesize, type, data, Zlib.crc32(type + data)].pack("NA4A*N") 
 end 
 def make_png(raw_data) 
   height = raw_data.size 
   width = raw_data[0].size 
   s = "\x89PNG\r\n\x1a\n".force_encoding("ascii-8bit") 
   s1 = chunk("IHDR", [width, height, 8, 2, 0, 0, 0].pack("NNCCCCC")) 
   s2 = chunk("IDAT", Zlib::Deflate.deflate(raw_data.map {|line| 
                        ([0] + line.flatten).pack("C*") }.join)) 
   s3 = chunk("IEND", "") 
   s + s1 + s2 + s3 
 end 
 def to_8bit(c) 
   if c.is_a?(Array) 
     if c[0].is_a?(Numeric) 
       c.map{|e| (e * 255).to_i } 
     else 
       raise "show(): bad array element " + c.to_s 
     end 
   else 
     [(c * 255).to_i] * 3 
   end 
 end 
 if !image.is_a?(Array) || !image[0].is_a?(Array) 
   puts "show(): not a 2d array" ; false 
 else 
   h = image.size 
   s = h < 10 ? 20 : h < 60 ? 10 : h < 400 ? 400 / h : 1 
   data = image.flat_map{|r| [r.flat_map{|c| [to_8bit(c)] * s }] * s} 
   IRuby.display make_png(data), mime: "image/png" ; true 
 end 
end 
 
 
def make2d(height,width) 
  Array.new(height){Array.new(width,0)} 
end   
 
def sphere(s) 
  image = make2d(s,s) 
  for y in 0..(s-1) 
    for x in 0..(s-1) 
      image[y][x] = b(s,x,y) 
    end 
  end 
  image 
end 
   
def b(s,x,y) 
  r = s/2 
  d = distance(x,y,r,r) 
  if d<=r 
    b=(r-d)/r 
  else 
    b=1 
  end 
end   
 
 
def distance(x,y,r,s) 
  sqrt((x-r)*(x-r)+(y-r)*(y-r)) 
end   
 
 
 
show(sphere(100))
# Out:
# "\x89PNG\r\n\x1A\n\x00\x00\x00\rIHDR\x00\x00\x01\x90\x00\x00\x01\x90\b\x02\x00\x00\x00\x0F\xDD\xA1\x9B\x00\x00/\x8BIDATx\x9C\xED\xDD}\xD0\xFEiY\xD7\xF1uqweWa!\x1EZ\x1Ed\x85\xC5\r1@\x1E\x05B\x17\\\x03$\xA5\x10Q\xC4\xD5\xC4%!\x9ET\x10\x05\x04AQQ\xC4\x87T\"\x850T\x12\v%\xA4\xD0P\xCB\xB1\xD0\xA2)\x9A\n{\x9A\x1E\xACf\xAAi\xAA\x99\x9Ai\xFA\xAB\x86\x99\x85y\xED\xB2\x9F\x1F\xC7\xF9\xFB^\xD7}\xDD\xD7}\x7F\xDE\x7F\xDE\\\xBF\xEF\xF7\xFC\x9E\x0Fov\x8E9\x8E\xF3\xB8\xE4\xFF\x95\xB2\a.\x81C\x8F\xA5\x9C\x1D\xBA\x99\xCA^\xA8\xB0\xCA>\xE8f*{\xA1\xC2*\xFB\xA0\x9B\xA9\xEC\x85\n\xAB\xEC\x83n\xA6s\x84\x12\xF94\xB8\x14\xEE\x10\xF8\xF4\x01\x97\r\x98<'\x8D\xC1q:\xFE\xCA\xF1\xF
# true

# %%
include(Math) 
 
require "zlib" 
def show(image) 
 def chunk(type, data) 
   [data.bytesize, type, data, Zlib.crc32(type + data)].pack("NA4A*N") 
 end 
 def make_png(raw_data) 
   height = raw_data.size 
   width = raw_data[0].size 
   s = "\x89PNG\r\n\x1a\n".force_encoding("ascii-8bit") 
   s1 = chunk("IHDR", [width, height, 8, 2, 0, 0, 0].pack("NNCCCCC")) 
   s2 = chunk("IDAT", Zlib::Deflate.deflate(raw_data.map {|line| 
                        ([0] + line.flatten).pack("C*") }.join)) 
   s3 = chunk("IEND", "") 
   s + s1 + s2 + s3 
 end 
 def to_8bit(c) 
   if c.is_a?(Array) 
     if c[0].is_a?(Numeric) 
       c.map{|e| (e * 255).to_i } 
     else 
       raise "show(): bad array element " + c.to_s 
     end 
   else 
     [(c * 255).to_i] * 3 
   end 
 end 
 if !image.is_a?(Array) || !image[0].is_a?(Array) 
   puts "show(): not a 2d array" ; false 
 else 
   h = image.size 
   s = h < 10 ? 20 : h < 60 ? 10 : h < 400 ? 400 / h : 1 
   data = image.flat_map{|r| [r.flat_map{|c| [to_8bit(c)] * s }] * s} 
   IRuby.display make_png(data), mime: "image/png" ; true 
 end 
end 
 
 
def make2d(height,width) 
  Array.new(height){Array.new(width,0)} 
end   
 
def sphere(s) 
  image = make2d(s,s) 
  for y in 0..(s-1) 
    for x in 0..(s-1) 
      image[y][x] = b(s,x,y) 
    end 
  end 
  image 
end 
   
def b(s,x,y) 
  r = s/2 
  d = distance(x,y,r,r) 
  if d<=r 
    b=1-(r-d)/r 
  else 
    b=1 
  end 
end   
 
 
def distance(x,y,r,s) 
  sqrt((x-r)*(x-r)+(y-r)*(y-r)) 
end   
 
 
 
show(sphere(100))
# Out:
# "\x89PNG\r\n\x1A\n\x00\x00\x00\rIHDR\x00\x00\x01\x90\x00\x00\x01\x90\b\x02\x00\x00\x00\x0F\xDD\xA1\x9B\x00\x00/+IDATx\x9C\xED\xDD{\xF0\xF6y]\xD7q\xFEi\x9A\xA9\x99j\x9Aj\xA6\xB2\xC3t\x92j\xA2&J)\xC7RI)$\x94\x12E%\t<\x84\x9A\aDQI\x10\x04\x14A\xE5\x14h+\x1EVD\x11\xB7\xD0V WX%@\x0E\xAE@\xAE\xB4\xB2\xE0r\xDC8\xB4\xEC\xAE\xEE\xAE\xBB+\xEB\xD6\xEC\xCC\xEE\xCCc\xF0~\xDD\xBC?\xF7\xF7\xBA\xEE\xEBw\xDD\xBF\xD7\xF3\xCF\xDF\\\xBF\xEF\xF7\xF3\xFD\x1C\x9E\x7F\xBC\xE7\xFD\xFE\xBC\xEF\xF5\xFFJ)\xE5H\xB8\xD7\xA1\aPJ)S*\xACR\xCA\xD1Pa\x95R\x8E\x86\n\xEB\x14q'\xFC\x01\xDC\x01\x1F\v\xFC\xFE\x80\xDB\aL\x9E\x93\xC6\xE08\x1D\xBF\xDFu\xE89.\xFB\xA5\xC2:ETX\xE5\xD8\xA9\xB0N\x11\x15V9v*\xACSD\x85U\x8E\x9D\n\xEB\x88\x99H